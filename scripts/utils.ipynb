# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

x_target = np.load('./devil-in-gan/data/art-dgm-ipynb-data/devil_image_normalised.npy')

print(x_target.shape)
plt.imshow(x_target[:,:,0], cmap='Greys_r',vmin=-1.0, vmax=1.0)
# plt.axis('off')


x_target_resize__image = cv2.resize(x_target, (32, 32))
x_target_resize = np.asarray(x_target_resize__image)


if x_target_resize.ndim == 2:
    x_target_resize = x_target_resize[:, :, None]


print(x_target_resize__image.shape, x_target_resize.shape)
# plt.imshow(x_target_resize__image, cmap='Greys_r')
# plt.axis('off')
# Out:
# (28, 28, 1)
# (32, 32) (32, 32, 1)

# %%
plt.imshow(x_target_resize[:, :, 0], cmap='Greys_r', vmin=-1.0, vmax=1.0)
plt.axis('off')
plt.show()
